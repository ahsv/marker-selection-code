# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd

# %%
# replace with path to the included version of picturedRocks on your system
import sys
sys.path.append('/home/ahsvargo/xvalid')

# %%
from picturedrocks import Rocks
from picturedrocks.performance import FoldTester, PerformanceReport, NearestCentroidClassifier

# %%
import plotly.graph_objs as go
from plotly.offline import plot, iplot, init_notebook_mode

# %%
import plotly.io as pio

# %%
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
import scanpy.api as sc
import anndata
# Out:
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/matplotlib/__init__.py:886: MatplotlibDeprecationWarning:
#
#
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.

# %%
import loadData as ld
# Out:
# scanpy==1.3.7+56.gde16b79.dirty anndata==0.6.11 numpy==1.14.6 scipy==1.1.0 pandas==0.23.4 scikit-learn==0.20.0 statsmodels==0.9.0 python-igraph==0.7.1 louvain==0.6.1

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
class RandomForest:
    def __init__(self):
        self.traindata = None
        self.RFC = RandomForestClassifier(n_estimators=100, n_jobs=-1)
        
    def train(self, data):
        self.traindata = data
        self.RFC.fit(data.X, data.y[:,0])
        
    def test(self, Xtest, sparse):
        return self.RFC.predict(Xtest)

# %% [markdown]
# ## Load data

# %% [markdown]
# ### Paul

# %%
rocks, ft = ld.load_paul('Rocks')
rocks.normalize(totalexpr=10000, log=True)
# Out:
# WARNING: In Scanpy 0.*, this returned logarithmized data. Now it returns non-logarithmized data.
# ... 100%
# ... storing 'paul15_clusters' as categorical
# Memory usage: current 0.32 GB, difference +0.32 GB

# %%
path = "paul/"
dataset = "paul15"

# %% [markdown]
# ### Zeisel

# %%
rocks, ft, = ld.load_zeisel('Rocks')
rocks.normalize(totalexpr=10000, log=True)

# %%
path = "zeisel/"
dataset = "zeisel"

# %% [markdown]
# ## Load markers

# %% [markdown]
# You will need to change these paths in order to load the markers.  See further on for loading the yhats.

# %%
methods = ['wilcoxon', 't-test_overestim_var', 'logreg']
meths = methods + ['edgeR', 'edgeRdet', 'MAST', 'MASTdet'] + ['enets', 'scvi', 'random'];

# %%
def load_markers(method, dataset, path, labels=""):
    
    # scanpy methods
    if method in ['wilcoxon', 't-test_overestim_var', 'logreg']:
        fname = path + dataset + "-" + method + "-markerList"
        if labels is "":
            fname += ".npz"
        else:
            fname += "-" + labels + ".npz"
        
        print("Loading markers from " + fname)
        
        pvalMarkerList = np.load(fname)['marks']
        pvalScoreList = np.load(fname)['pvals']
       
    # R based methods
    elif method in ['edgeR', 'edgeRdet', 'MAST', 'MASTdet']:
        if dataset is not "paul15" and dataset is not "zeisel":
            print("Error: R methods only run on datasets 'paul15' and 'zeisel'")
            return
        
        pmethods = ["edgeR/", 'edgeRdet/', 'MASTtpm/', 'MASTtpmDet/']
        zmethods = ["edgeR/", 'edgeRdet/', 'MAST/', 'MASTdet/']
        ind = ["edgeR", 'edgeRdet', 'MAST', 'MASTdet'].index(method)
        
        if dataset is "paul15":
            method  = pmethods[ind]
        else:
            method = zmethods[ind]
            
        pvalMarkerList = []
        for fold in range(5):
            dayta = np.load(path + method + "markerList-fold" + str(fold) + ".npz")
            pvalMarkerList.append(dayta['arr_0'])
            
    # random markers
    elif method is "random":
        pvalMarkerList = np.load(dataset + "-randomMarkers.npz")['arr_0']
        
    # scvi    
    elif method is "scvi":
        path="./scvi/"
        pvalMarkerList = []
        for fold in range(5):
            dayta = np.load(path + dataset + "-scvi-marks-fold" + str(fold) + ".npz")
            pvalMarkerList.append(dayta['arr_0'])
            
    # elastic nets
    elif method is "enets":
        path = "./enets/"
        pvalMarkerList = []
        for fold in range(5):
            dayta = np.load(path + dataset + "-nets-fold" + str(fold) + "-marks.npz")
            pvalMarkerList.append(dayta['arr_0'])
            
    else: 
        print("Error: Method must be one of the following:")
        print("'wilcoxon', 't-test_overestim_var', 'logreg', 'edgeR', 'edgeRdet', 'MAST', 'MASTdet', 'random', 'scvi', 'enets'")
        print("Return None")
        return None
    
    return pvalMarkerList

# %%
meths = methods + ['edgeR', 'edgeRdet', 'MAST', 'MASTdet'] + ['enets', 'scvi', 'random'];
method = methods[0]

# %%
pvalMarkerList = load_markers(method, dataset=dataset, path=path)
# Out:
# Loading markers from zeisel/zeisel-wilcoxon-markerList.npz

# %% [markdown]
# ## Collect y hat data
# For p value methods.  See the notebook `1bcs.ipynb` for more the y hats for RankCorr and Spa.  Again, see below to load these yhat data that has already been collected.

# %%
marks_list = [2,3,4,5,6,7,8,9,10,12,14,16,18,20,25,30,35,40,45,50,55,60,65,70,75]

def classify(ft, pvalMarkerList, marks_list=marks_list, classifier=NearestCentroidClassifier):
    xvals = []
    yhats = []

    for marks_per_clust in marks_list:

        print("markers per cluster: {}".format(marks_per_clust), flush=True)
        myMarks = [list(set().union(*[marks[:marks_per_clust] for marks in table])) for table in pvalMarkerList]
        ft.markers = myMarks

        print("Number of markers per fold: {}".format([len(a) for a in ft.markers]))
        xvals.append([len(a) for a in ft.markers])

        ft.classify(classifier)
        yhats.append(ft.yhat)
        
    return xvals, yhats

# %%
# %%time
xvals, yhats = classify(ft, pvalMarkerList, classifier=NearestCentroidClassifier)
# Out:
# markers per cluster: 2
# Number of markers per fold: [18, 18, 18, 18, 18]
# markers per cluster: 3
# Number of markers per fold: [27, 26, 27, 27, 27]
# markers per cluster: 4
# Number of markers per fold: [36, 35, 35, 36, 36]
# markers per cluster: 5
# Number of markers per fold: [44, 43, 43, 43, 44]
# markers per cluster: 6
# Number of markers per fold: [53, 52, 51, 51, 53]
# markers per cluster: 7
# Number of markers per fold: [62, 60, 60, 60, 61]
# markers per cluster: 8
# Number of markers per fold: [71, 69, 68, 69, 69]
# markers per cluster: 9
# Number of markers per fold: [79, 78, 77, 78, 78]
# markers per cluster: 10
# Number of markers per fold: [88, 86, 86, 87, 87]
# markers per cluster: 12
# Number of markers per fold: [104, 103, 102, 103, 104]
# markers per cluster: 14
# Number of markers per fold: [121, 118, 118, 120, 120]
# markers per cluster: 16
# Number of markers per fold: [138, 134, 136, 137, 135]
# markers per cluster: 18
# Number of markers per fold: [156, 148, 151, 155, 151]
# markers per cluster: 20
# Number of markers per fold: [169, 162, 167, 170, 165]
# markers per cluster: 25
# Number of markers per fold: [206, 197, 205, 208, 201]
# markers per cluster: 30
# Number of markers per fold: [241, 229, 239, 242, 235]
# markers per cluster: 35
# Number of markers per fold: [274, 262, 272, 272, 266]
# markers per cluster: 40
# Number of markers per fold: [311, 297, 301, 308, 300]
# markers per cluster: 45
# Number of markers per fold: [342, 333, 336, 343, 335]
# markers per cluster: 50
# Number of markers per fold: [373, 364, 372, 373, 370]
# markers per cluster: 55
# Number of markers per fold: [403, 394, 402, 401, 396]
# markers per cluster: 60
# Number of markers per fold: [432, 421, 427, 432, 423]
# markers per cluster: 65
# Number of markers per fold: [455, 445, 458, 457, 449]
# markers per cluster: 70
# Number of markers per fold: [481, 466, 484, 478, 473]
# markers per cluster: 75
# Number of markers per fold: [506, 494, 506, 501, 494]
# CPU times: user 14.4 s, sys: 4.08 s, total: 18.5 s
# Wall time: 18.5 s

# %%
np.array([np.array(a).mean() for a in xvals])
# Out:
# array([ 18. ,  26.8,  35.6,  43.4,  52. ,  60.6,  69.2,  78. ,  86.8,
#        103.2, 119.4, 136. , 152.2, 166.6, 203.4, 237.2, 269.2, 303.4,
#        337.8, 370.4, 399.2, 427. , 452.8, 476.4, 500.2])

# %%
errs = np.array(list( map(lambda yhat: rocks.X.shape[0] - np.where(yhat == rocks.y.flatten())[0].shape[0], yhats) ))
errs
# Out:
# array([334, 333, 284, 251, 228, 213, 200, 200, 191, 192, 193, 185, 181,
#        174, 162, 157, 150, 151, 142, 141, 137, 136, 135, 136, 138])

# %%
rocks.X.shape
# Out:
# (3005, 4999)

# %% [markdown]
# Collect all of the data for all of the methods at once and save it.

# %%
# %%time
for method in meths:
    print("######## Working on method {}".format(method), flush=True)
    pvalMarkerList = load_markers(method, dataset=dataset, path=path)
    
    xvals, yhats = classify(ft, pvalMarkerList, classifier=NearestCentroidClassifier)
    errs = np.array(list( map(lambda yhat: rocks.X.shape[0] - np.where(yhat == rocks.y.flatten())[0].shape[0], yhats) ))
    
    outname = dataset + "-" + method + "-plotInfo.npz"
    print('######## Saving data to {}'.format(outname))
    np.savez(path + outname, xvals=xvals, yhats=yhats, ytrue=rocks.y, marks=marks_list, errs=errs)
# Out:
# ######## Working on method wilcoxon
# Loading markers from zeisel/zeisel-wilcoxon-markerList.npz
# markers per cluster: 2
# Number of markers per fold: [18, 18, 18, 18, 18]
# markers per cluster: 3
# Number of markers per fold: [27, 26, 27, 27, 27]
# markers per cluster: 4
# Number of markers per fold: [36, 35, 35, 36, 36]
# markers per cluster: 5
# Number of markers per fold: [44, 43, 43, 43, 44]
# markers per cluster: 6
# Number of markers per fold: [53, 52, 51, 51, 53]
# markers per cluster: 7
# Number of markers per fold: [62, 60, 60, 60, 61]
# markers per cluster: 8
# Number of markers per fold: [71, 69, 68, 69, 69]
# markers per cluster: 9
# Number of markers per fold: [79, 78, 77, 78, 78]
# markers per cluster: 10
# Number of markers per fold: [88, 86, 86, 87, 87]
# markers per cluster: 12
# Number of markers per fold: [104, 103, 102, 103, 104]
# markers per cluster: 14
# Number of markers per fold: [121, 118, 118, 120, 120]
# markers per cluster: 16
# Number of markers per fold: [138, 134, 136, 137, 135]
# markers per cluster: 18
# Number of markers per fold: [156, 148, 151, 155, 151]
# markers per cluster: 20
# Number of markers per fold: [169, 162, 167, 170, 165]
# markers per cluster: 25
# Number of markers per fold: [206, 197, 205, 208, 201]
# markers per cluster: 30
# Number of markers per fold: [241, 229, 239, 242, 235]
# markers per cluster: 35
# Number of markers per fold: [274, 262, 272, 272, 266]
# markers per cluster: 40
# Number of markers per fold: [311, 297, 301, 308, 300]
# markers per cluster: 45
# Number of markers per fold: [342, 333, 336, 343, 335]
# markers per cluster: 50
# Number of markers per fold: [373, 364, 372, 373, 370]
# markers per cluster: 55
# Number of markers per fold: [403, 394, 402, 401, 396]
# markers per cluster: 60
# Number of markers per fold: [432, 421, 427, 432, 423]
# markers per cluster: 65
# Number of markers per fold: [455, 445, 458, 457, 449]
# markers per cluster: 70
# Number of markers per fold: [481, 466, 484, 478, 473]
# markers per cluster: 75
# Number of markers per fold: [506, 494, 506, 501, 494]
# ######## Saving data to zeisel-wilcoxon-plotInfo.npz
# ######## Working on method t-test_overestim_var
# Loading markers from zeisel/zeisel-t-test_overestim_var-markerList.npz
# markers per cluster: 2
# Number of markers per fold: [18, 18, 18, 18, 18]
# markers per cluster: 3
# Number of markers per fold: [27, 27, 27, 27, 27]
# markers per cluster: 4
# Number of markers per fold: [36, 36, 36, 36, 36]
# markers per cluster: 5
# Number of markers per fold: [45, 45, 45, 45, 45]
# markers per cluster: 6
# Number of markers per fold: [54, 54, 54, 54, 54]
# markers per cluster: 7
# Number of markers per fold: [63, 62, 63, 63, 63]
# markers per cluster: 8
# Number of markers per fold: [71, 71, 71, 72, 72]
# markers per cluster: 9
# Number of markers per fold: [80, 80, 80, 81, 81]
# markers per cluster: 10
# Number of markers per fold: [89, 88, 88, 90, 89]
# markers per cluster: 12
# Number of markers per fold: [107, 105, 106, 108, 106]
# markers per cluster: 14
# Number of markers per fold: [123, 121, 124, 124, 123]
# markers per cluster: 16
# Number of markers per fold: [140, 136, 138, 141, 139]
# markers per cluster: 18
# Number of markers per fold: [155, 150, 154, 157, 154]
# markers per cluster: 20
# Number of markers per fold: [172, 163, 168, 172, 169]
# markers per cluster: 25
# Number of markers per fold: [210, 198, 205, 209, 205]
# markers per cluster: 30
# Number of markers per fold: [245, 230, 239, 243, 239]
# markers per cluster: 35
# Number of markers per fold: [280, 265, 272, 282, 275]
# markers per cluster: 40
# Number of markers per fold: [311, 294, 307, 314, 305]
# markers per cluster: 45
# Number of markers per fold: [345, 322, 341, 344, 339]
# markers per cluster: 50
# Number of markers per fold: [373, 348, 370, 376, 371]
# markers per cluster: 55
# Number of markers per fold: [396, 374, 396, 396, 395]
# markers per cluster: 60
# Number of markers per fold: [419, 396, 418, 420, 419]
# markers per cluster: 65
# Number of markers per fold: [446, 418, 443, 447, 445]
# markers per cluster: 70
# Number of markers per fold: [469, 443, 463, 469, 465]
# markers per cluster: 75
# Number of markers per fold: [492, 469, 484, 489, 484]
# ######## Saving data to zeisel-t-test_overestim_var-plotInfo.npz
# ######## Working on method logreg
# Loading markers from zeisel/zeisel-logreg-markerList.npz
# markers per cluster: 2
# Number of markers per fold: [17, 17, 16, 16, 16]
# markers per cluster: 3
# Number of markers per fold: [25, 24, 24, 24, 25]
# markers per cluster: 4
# Number of markers per fold: [31, 31, 31, 33, 32]
# markers per cluster: 5
# Number of markers per fold: [38, 38, 38, 38, 37]
# markers per cluster: 6
# Number of markers per fold: [45, 45, 45, 44, 43]
# markers per cluster: 7
# Number of markers per fold: [51, 51, 52, 52, 49]
# markers per cluster: 8
# Number of markers per fold: [59, 56, 60, 59, 54]
# markers per cluster: 9
# Number of markers per fold: [66, 64, 67, 65, 61]
# markers per cluster: 10
# Number of markers per fold: [73, 68, 73, 71, 67]
# markers per cluster: 12
# Number of markers per fold: [85, 79, 84, 82, 78]
# markers per cluster: 14
# Number of markers per fold: [94, 89, 95, 96, 94]
# markers per cluster: 16
# Number of markers per fold: [106, 99, 108, 104, 102]
# markers per cluster: 18
# Number of markers per fold: [115, 108, 119, 117, 113]
# markers per cluster: 20
# Number of markers per fold: [126, 119, 128, 129, 121]
# markers per cluster: 25
# Number of markers per fold: [146, 146, 153, 147, 148]
# markers per cluster: 30
# Number of markers per fold: [170, 163, 176, 174, 170]
# markers per cluster: 35
# Number of markers per fold: [193, 186, 195, 192, 199]
# markers per cluster: 40
# Number of markers per fold: [216, 211, 219, 211, 220]
# markers per cluster: 45
# Number of markers per fold: [242, 229, 238, 236, 244]
# markers per cluster: 50
# Number of markers per fold: [264, 248, 257, 260, 263]
# markers per cluster: 55
# Number of markers per fold: [280, 267, 280, 282, 277]
# markers per cluster: 60
# Number of markers per fold: [296, 288, 298, 305, 292]
# markers per cluster: 65
# Number of markers per fold: [311, 306, 312, 319, 304]
# markers per cluster: 70
# Number of markers per fold: [328, 325, 325, 336, 324]
# markers per cluster: 75
# Number of markers per fold: [345, 346, 340, 351, 342]
# ######## Saving data to zeisel-logreg-plotInfo.npz
# ######## Working on method edgeR
# markers per cluster: 2
# Number of markers per fold: [18, 18, 18, 18, 18]
# markers per cluster: 3
# Number of markers per fold: [27, 27, 27, 27, 27]
# markers per cluster: 4
# Number of markers per fold: [36, 36, 36, 36, 36]
# markers per cluster: 5
# Number of markers per fold: [45, 45, 45, 45, 45]
# markers per cluster: 6
# Number of markers per fold: [54, 54, 54, 54, 54]
# markers per cluster: 7
# Number of markers per fold: [63, 63, 63, 63, 63]
# markers per cluster: 8
# Number of markers per fold: [72, 72, 72, 72, 72]
# markers per cluster: 9
# Number of markers per fold: [81, 81, 81, 81, 81]
# markers per cluster: 10
# Number of markers per fold: [90, 90, 90, 90, 90]
# markers per cluster: 12
# Number of markers per fold: [108, 108, 108, 108, 108]
# markers per cluster: 14
# Number of markers per fold: [126, 126, 126, 126, 126]
# markers per cluster: 16
# Number of markers per fold: [144, 144, 144, 144, 144]
# markers per cluster: 18
# Number of markers per fold: [162, 162, 162, 162, 162]
# markers per cluster: 20
# Number of markers per fold: [180, 180, 180, 180, 180]
# markers per cluster: 25
# Number of markers per fold: [225, 224, 224, 224, 225]
# markers per cluster: 30
# Number of markers per fold: [269, 269, 269, 268, 268]
# markers per cluster: 35
# Number of markers per fold: [313, 312, 313, 313, 313]
# markers per cluster: 40
# Number of markers per fold: [357, 356, 356, 357, 358]
# markers per cluster: 45
# Number of markers per fold: [397, 399, 395, 396, 402]
# markers per cluster: 50
# Number of markers per fold: [438, 439, 437, 435, 442]
# markers per cluster: 55
# Number of markers per fold: [478, 479, 476, 478, 479]
# markers per cluster: 60
# Number of markers per fold: [520, 519, 514, 517, 518]
# markers per cluster: 65
# Number of markers per fold: [555, 559, 555, 555, 557]
# markers per cluster: 70
# Number of markers per fold: [590, 596, 597, 593, 600]
# markers per cluster: 75
# Number of markers per fold: [627, 636, 637, 631, 639]
# ######## Saving data to zeisel-edgeR-plotInfo.npz
# ######## Working on method edgeRdet
# markers per cluster: 2
# Number of markers per fold: [18, 18, 18, 18, 18]
# markers per cluster: 3
# Number of markers per fold: [27, 27, 27, 27, 27]
# markers per cluster: 4
# Number of markers per fold: [36, 36, 36, 36, 36]
# markers per cluster: 5
# Number of markers per fold: [45, 45, 45, 45, 45]
# markers per cluster: 6
# Number of markers per fold: [54, 54, 54, 54, 54]
# markers per cluster: 7
# Number of markers per fold: [63, 63, 63, 63, 63]
# markers per cluster: 8
# Number of markers per fold: [72, 72, 72, 72, 72]
# markers per cluster: 9
# Number of markers per fold: [81, 81, 81, 81, 81]
# markers per cluster: 10
# Number of markers per fold: [90, 90, 90, 90, 90]
# markers per cluster: 12
# Number of markers per fold: [108, 108, 108, 108, 108]
# markers per cluster: 14
# Number of markers per fold: [126, 126, 126, 126, 126]
# markers per cluster: 16
# Number of markers per fold: [144, 144, 144, 144, 144]
# markers per cluster: 18
# Number of markers per fold: [162, 162, 162, 162, 162]
# markers per cluster: 20
# Number of markers per fold: [180, 180, 180, 180, 180]
# markers per cluster: 25
# Number of markers per fold: [224, 225, 224, 224, 225]
# markers per cluster: 30
# Number of markers per fold: [269, 267, 268, 268, 268]
# markers per cluster: 35
# Number of markers per fold: [313, 311, 311, 313, 313]
# markers per cluster: 40
# Number of markers per fold: [355, 352, 354, 357, 357]
# markers per cluster: 45
# Number of markers per fold: [393, 392, 392, 392, 398]
# markers per cluster: 50
# Number of markers per fold: [433, 433, 433, 431, 435]
# markers per cluster: 55
# Number of markers per fold: [472, 475, 472, 472, 478]
# markers per cluster: 60
# Number of markers per fold: [511, 514, 512, 514, 518]
# markers per cluster: 65
# Number of markers per fold: [552, 554, 554, 552, 558]
# markers per cluster: 70
# Number of markers per fold: [591, 594, 594, 592, 596]
# markers per cluster: 75
# Number of markers per fold: [629, 633, 634, 631, 634]
# ######## Saving data to zeisel-edgeRdet-plotInfo.npz
# ######## Working on method MAST
# markers per cluster: 2
# Number of markers per fold: [18, 18, 18, 18, 18]
# markers per cluster: 3
# Number of markers per fold: [27, 27, 27, 27, 27]
# markers per cluster: 4
# Number of markers per fold: [36, 36, 36, 36, 36]
# markers per cluster: 5
# Number of markers per fold: [45, 45, 45, 45, 45]
# markers per cluster: 6
# Number of markers per fold: [54, 54, 54, 54, 54]
# markers per cluster: 7
# Number of markers per fold: [63, 63, 63, 63, 63]
# markers per cluster: 8
# Number of markers per fold: [72, 72, 72, 72, 72]
# markers per cluster: 9
# Number of markers per fold: [81, 81, 81, 81, 81]
# markers per cluster: 10
# Number of markers per fold: [90, 90, 90, 90, 90]
# markers per cluster: 12
# Number of markers per fold: [108, 108, 108, 108, 108]
# markers per cluster: 14
# Number of markers per fold: [126, 126, 126, 126, 126]
# markers per cluster: 16
# Number of markers per fold: [144, 144, 144, 144, 144]
# markers per cluster: 18
# Number of markers per fold: [162, 162, 162, 162, 162]
# markers per cluster: 20
# Number of markers per fold: [180, 180, 180, 180, 180]
# markers per cluster: 25
# Number of markers per fold: [224, 224, 225, 225, 225]
# markers per cluster: 30
# Number of markers per fold: [269, 268, 269, 269, 269]
# markers per cluster: 35
# Number of markers per fold: [313, 312, 314, 313, 312]
# markers per cluster: 40
# Number of markers per fold: [356, 355, 356, 357, 357]
# markers per cluster: 45
# Number of markers per fold: [398, 398, 400, 400, 400]
# markers per cluster: 50
# Number of markers per fold: [441, 438, 441, 442, 441]
# markers per cluster: 55
# Number of markers per fold: [480, 475, 478, 478, 479]
# markers per cluster: 60
# Number of markers per fold: [515, 514, 511, 516, 514]
# markers per cluster: 65
# Number of markers per fold: [548, 544, 544, 548, 544]
# markers per cluster: 70
# Number of markers per fold: [582, 578, 579, 577, 576]
# markers per cluster: 75
# Number of markers per fold: [616, 615, 613, 610, 613]
# ######## Saving data to zeisel-MAST-plotInfo.npz
# ######## Working on method MASTdet
# markers per cluster: 2
# Number of markers per fold: [18, 18, 18, 18, 18]
# markers per cluster: 3
# Number of markers per fold: [27, 27, 27, 27, 27]
# markers per cluster: 4
# Number of markers per fold: [36, 36, 36, 36, 36]
# markers per cluster: 5
# Number of markers per fold: [45, 45, 45, 45, 45]
# markers per cluster: 6
# Number of markers per fold: [54, 54, 54, 54, 54]
# markers per cluster: 7
# Number of markers per fold: [63, 63, 63, 63, 63]
# markers per cluster: 8
# Number of markers per fold: [72, 72, 72, 72, 72]
# markers per cluster: 9
# Number of markers per fold: [81, 81, 81, 81, 81]
# markers per cluster: 10
# Number of markers per fold: [90, 90, 90, 90, 90]
# markers per cluster: 12
# Number of markers per fold: [108, 108, 108, 108, 108]
# markers per cluster: 14
# Number of markers per fold: [126, 126, 126, 126, 126]
# markers per cluster: 16
# Number of markers per fold: [144, 144, 144, 144, 144]
# markers per cluster: 18
# Number of markers per fold: [162, 162, 162, 162, 162]
# markers per cluster: 20
# Number of markers per fold: [180, 180, 180, 180, 180]
# markers per cluster: 25
# Number of markers per fold: [224, 224, 225, 225, 225]
# markers per cluster: 30
# Number of markers per fold: [269, 269, 269, 269, 270]
# markers per cluster: 35
# Number of markers per fold: [313, 313, 314, 314, 313]
# markers per cluster: 40
# Number of markers per fold: [356, 355, 356, 357, 357]
# markers per cluster: 45
# Number of markers per fold: [398, 396, 399, 400, 399]
# markers per cluster: 50
# Number of markers per fold: [443, 439, 441, 441, 442]
# markers per cluster: 55
# Number of markers per fold: [483, 480, 477, 479, 482]
# markers per cluster: 60
# Number of markers per fold: [516, 514, 510, 516, 516]
# markers per cluster: 65
# Number of markers per fold: [548, 544, 548, 552, 548]
# markers per cluster: 70
# Number of markers per fold: [584, 579, 582, 584, 585]
# markers per cluster: 75
# Number of markers per fold: [618, 616, 613, 612, 614]
# ######## Saving data to zeisel-MASTdet-plotInfo.npz
# ######## Working on method enets
# markers per cluster: 2
# Number of markers per fold: [9, 9, 9, 9, 11]
# markers per cluster: 3
# Number of markers per fold: [13, 13, 13, 13, 16]
# markers per cluster: 4
# Number of markers per fold: [17, 17, 17, 17, 20]
# markers per cluster: 5
# Number of markers per fold: [20, 21, 20, 20, 23]
# markers per cluster: 6
# Number of markers per fold: [24, 23, 24, 24, 27]
# markers per cluster: 7
# Number of markers per fold: [27, 26, 28, 28, 31]
# markers per cluster: 8
# Number of markers per fold: [30, 30, 32, 32, 34]
# markers per cluster: 9
# Number of markers per fold: [34, 33, 35, 35, 38]
# markers per cluster: 10
# Number of markers per fold: [36, 37, 38, 38, 39]
# markers per cluster: 12
# Number of markers per fold: [40, 40, 41, 42, 44]
# markers per cluster: 14
# Number of markers per fold: [43, 45, 44, 44, 48]
# markers per cluster: 16
# Number of markers per fold: [47, 47, 47, 46, 50]
# markers per cluster: 18
# Number of markers per fold: [50, 50, 48, 50, 52]
# markers per cluster: 20
# Number of markers per fold: [52, 53, 52, 54, 53]
# markers per cluster: 25
# Number of markers per fold: [60, 61, 61, 62, 61]
# markers per cluster: 30
# Number of markers per fold: [67, 70, 68, 69, 68]
# markers per cluster: 35
# Number of markers per fold: [74, 76, 73, 75, 75]
# markers per cluster: 40
# Number of markers per fold: [78, 83, 78, 79, 80]
# markers per cluster: 45
# Number of markers per fold: [80, 89, 84, 85, 88]
# markers per cluster: 50
# Number of markers per fold: [82, 96, 89, 90, 93]
# markers per cluster: 55
# Number of markers per fold: [87, 100, 94, 94, 102]
# markers per cluster: 60
# Number of markers per fold: [89, 109, 96, 98, 104]
# markers per cluster: 65
# Number of markers per fold: [90, 113, 98, 102, 110]
# markers per cluster: 70
# Number of markers per fold: [90, 118, 98, 106, 114]
# markers per cluster: 75
# Number of markers per fold: [90, 123, 98, 109, 120]
# ######## Saving data to zeisel-enets-plotInfo.npz
# ######## Working on method scvi
# markers per cluster: 2
# Number of markers per fold: [18, 18, 18, 18, 18]
# markers per cluster: 3
# Number of markers per fold: [27, 27, 27, 27, 27]
# markers per cluster: 4
# Number of markers per fold: [36, 36, 36, 36, 36]
# markers per cluster: 5
# Number of markers per fold: [45, 45, 45, 45, 45]
# markers per cluster: 6
# Number of markers per fold: [54, 54, 54, 54, 54]
# markers per cluster: 7
# Number of markers per fold: [63, 63, 63, 63, 63]
# markers per cluster: 8
# Number of markers per fold: [72, 72, 72, 72, 72]
# markers per cluster: 9
# Number of markers per fold: [81, 81, 81, 81, 81]
# markers per cluster: 10
# Number of markers per fold: [90, 90, 90, 90, 90]
# markers per cluster: 12
# Number of markers per fold: [108, 108, 108, 108, 108]
# markers per cluster: 14
# Number of markers per fold: [126, 126, 126, 126, 126]
# markers per cluster: 16
# Number of markers per fold: [144, 144, 144, 144, 144]
# markers per cluster: 18
# Number of markers per fold: [162, 162, 162, 162, 162]
# markers per cluster: 20
# Number of markers per fold: [180, 180, 180, 180, 180]
# markers per cluster: 25
# Number of markers per fold: [225, 225, 225, 225, 225]
# markers per cluster: 30
# Number of markers per fold: [270, 270, 269, 270, 269]
# markers per cluster: 35
# Number of markers per fold: [315, 315, 314, 314, 314]
# markers per cluster: 40
# Number of markers per fold: [360, 359, 357, 359, 359]
# markers per cluster: 45
# Number of markers per fold: [405, 404, 401, 404, 404]
# markers per cluster: 50
# Number of markers per fold: [450, 446, 445, 448, 448]
# markers per cluster: 55
# Number of markers per fold: [495, 491, 488, 491, 492]
# markers per cluster: 60
# Number of markers per fold: [539, 536, 532, 536, 536]
# markers per cluster: 65
# Number of markers per fold: [583, 580, 576, 580, 580]
# markers per cluster: 70
# Number of markers per fold: [628, 623, 621, 623, 623]
# markers per cluster: 75
# Number of markers per fold: [672, 662, 663, 667, 668]
# ######## Saving data to zeisel-scvi-plotInfo.npz
# ######## Working on method random
# markers per cluster: 2
# Number of markers per fold: [18, 18, 18, 18, 18]
# markers per cluster: 3
# Number of markers per fold: [26, 27, 27, 27, 27]
# markers per cluster: 4
# Number of markers per fold: [35, 36, 36, 36, 36]
# markers per cluster: 5
# Number of markers per fold: [44, 45, 45, 45, 45]
# markers per cluster: 6
# Number of markers per fold: [53, 54, 54, 54, 53]
# markers per cluster: 7
# Number of markers per fold: [62, 63, 63, 63, 62]
# markers per cluster: 8
# Number of markers per fold: [71, 72, 72, 71, 71]
# markers per cluster: 9
# Number of markers per fold: [79, 81, 81, 80, 80]
# markers per cluster: 10
# Number of markers per fold: [88, 90, 89, 89, 89]
# markers per cluster: 12
# Number of markers per fold: [106, 108, 107, 107, 106]
# markers per cluster: 14
# Number of markers per fold: [123, 126, 125, 125, 124]
# markers per cluster: 16
# Number of markers per fold: [140, 143, 143, 142, 142]
# markers per cluster: 18
# Number of markers per fold: [158, 159, 161, 160, 160]
# markers per cluster: 20
# Number of markers per fold: [174, 176, 179, 177, 177]
# markers per cluster: 25
# Number of markers per fold: [218, 221, 223, 221, 221]
# markers per cluster: 30
# Number of markers per fold: [263, 264, 266, 264, 263]
# markers per cluster: 35
# Number of markers per fold: [305, 304, 310, 308, 307]
# markers per cluster: 40
# Number of markers per fold: [349, 345, 349, 350, 347]
# markers per cluster: 45
# Number of markers per fold: [391, 387, 390, 392, 385]
# markers per cluster: 50
# Number of markers per fold: [436, 430, 432, 433, 426]
# markers per cluster: 55
# Number of markers per fold: [480, 472, 474, 475, 465]
# markers per cluster: 60
# Number of markers per fold: [521, 512, 514, 514, 509]
# markers per cluster: 65
# Number of markers per fold: [560, 555, 551, 556, 550]
# markers per cluster: 70
# Number of markers per fold: [600, 597, 595, 594, 588]
# markers per cluster: 75
# Number of markers per fold: [641, 637, 633, 635, 628]
# ######## Saving data to zeisel-random-plotInfo.npz
# CPU times: user 2min 25s, sys: 43.2 s, total: 3min 8s
# Wall time: 3min 8s

# %% [markdown]
# ## Aggregate the data and compute the values mentioned in the paper.
#
# This point to the correct location to find the plotInfo information and can be run right now.

# %%
import sklearn.metrics as skm

# %%
methods = ['wilcoxon', 't-test_overestim_var', 'logreg']
meths = methods + ['edgeR', 'edgeRdet', 'MAST', 'MASTdet'] + ['enets', 'genzel', 'scvi',  'random'];

# %%
dataset = "paul15"
path = "../paul/plot/"

# %%
yTrue = rocks.y

accs = []
prec = []
recs = []
mccs = []
xvals = []

for method in ['rankCorr'] + meths:
    
    #if method is 
    fname = dataset + "-" + method + "-plotInfo-RF.npz"
    print("PROCESSING DATA FROM {}".format(path + fname))
    
    dayta = np.load(path + fname) 
    
    accs.append( list(map(lambda yhat: 1-skm.accuracy_score(yTrue, yhat), dayta['yhats'])) )
    prec.append( list(map(lambda yhat: skm.precision_score(yTrue, yhat, average='weighted'), dayta['yhats'])) )
    recs.append( list(map(lambda yhat: skm.recall_score(yTrue, yhat, average='weighted'), dayta['yhats'])) )
    mccs.append( list(map(lambda yhat: skm.matthews_corrcoef(yTrue, yhat), dayta['yhats'])) )
    
    xvals.append( np.array([np.array(a).mean() for a in dayta['xvals']]) )
    
    dayta.close()
    
outname = dataset +  "-class-scores-RF.npz"
print("Saving all processed data to {}".format(path + outname))

np.savez(path + outname, accs=accs, prec=prec, recs=recs, mccs=mccs, xvals=xvals)
# Out:
# PROCESSING DATA FROM ../paul/plot/paul15-rankCorr-plotInfo-RF.npz
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
# PROCESSING DATA FROM ../paul/plot/paul15-wilcoxon-plotInfo-RF.npz
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
# PROCESSING DATA FROM ../paul/plot/paul15-t-test_overestim_var-plotInfo-RF.npz
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
# PROCESSING DATA FROM ../paul/plot/paul15-logreg-plotInfo-RF.npz
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
# PROCESSING DATA FROM ../paul/plot/paul15-edgeR-plotInfo-RF.npz
# PROCESSING DATA FROM ../paul/plot/paul15-edgeRdet-plotInfo-RF.npz
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
# PROCESSING DATA FROM ../paul/plot/paul15-MAST-plotInfo-RF.npz
# PROCESSING DATA FROM ../paul/plot/paul15-MASTdet-plotInfo-RF.npz
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
# PROCESSING DATA FROM ../paul/plot/paul15-enets-plotInfo-RF.npz
# PROCESSING DATA FROM ../paul/plot/paul15-genzel-plotInfo-RF.npz
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
# PROCESSING DATA FROM ../paul/plot/paul15-scvi-plotInfo-RF.npz
# PROCESSING DATA FROM ../paul/plot/paul15-random-plotInfo-RF.npz
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
# Saving all processed data to ../paul/plot/paul15-class-scores-RF.npz
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /home/ahsvargo/miniconda3/envs/r35py37/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.

# %% [markdown]
# Precisions and accuracies are very similar.  Do a couple of tests to make sure that we are correct.
#
# It seems that we are correct, at least on Paul...  Not sure how to explain this, since accuracies are generally pretty low.

# %%
fname = dataset + "-" + "rankCorr-plotInfo-RF.npz"
dayta = np.load(path + fname)
yhats = dayta['yhats']
ytrue = rocks.y.flatten()

# %%
len(list(set(np.where(yhats[0] == 1)[0]).intersection(set(np.where(ytrue == 1)[0]))))
# Out:
# 245

# %%
(1 * np.logical_and(yhats[0]==1, ytrue==1)).sum()
# Out:
# 245

# %%
def precAcc(yhat, ytrue):
    
    N = yhat.shape[0]
    
    classes = np.unique(ytrue)
    predCounts = np.array([
        np.where(yhat == clust)[0].shape[0] for clust in classes
    ])
    # deal with undefined cases
    predCounts[predCounts==0] = 1
    
    trueCounts = np.array([
        np.where(ytrue == clust)[0].shape[0] for clust in classes 
    ])
    
    corrCounts = np.array([
        (1 * np.logical_and(yhat==clust, ytrue==clust)).sum() for clust in classes
    ])
    
    precs = corrCounts / predCounts * trueCounts
    
    return precs.sum()/N, corrCounts.sum()/N#, corrCounts, predCounts, trueCounts

# %%
myPrecs = []
myAccs = []

for yhat in yhats:
    p, a = precAcc(yhat, ytrue)
    myPrecs.append(p)
    myAccs.append(a)

myPrecs = np.array(myPrecs)
myAccs = np.array(myAccs)

# %%
RFname = dataset + "-class-scores-RF.npz"
RF = np.load(path + RFname)
calcPrecs = RF['prec'][0]
calcAccs = RF['accs'][0]

# %%
np.nonzero(myPrecs - np.array(calcPrecs))
# Out:
# (array([], dtype=int64),)

# %%
np.nonzero(1 - myAccs - np.array(calcAccs))
# Out:
# (array([], dtype=int64),)

# %%
prec = 0
for i, numCorr in enumerate(corr):
    prec += numCorr/pred[i] * true[i]
    
prec/rocks.X.shape[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-6b2b400b37b2> in <module>
#       1 prec = 0
# ----> 2 for i, numCorr in enumerate(corr):
#       3     prec += numCorr/pred[i] * true[i]
#       4
#       5 prec/rocks.X.shape[0]
#
# NameError: name 'corr' is not defined

# %%
p
# Out:
# 0.6553252359753782

# %%
true/pred
# Out:
# array([2.15      , 0.80048662, 1.01234568, 2.10169492, 1.        ,
#        0.98295455, 0.76958525, 1.17241379, 6.3       , 0.83606557,
#        1.        , 1.11290323, 0.98039216, 0.86542923, 1.24832215,
#        1.03144654, 3.14285714, 2.25      , 1.24      ])

# %%
true
# Out:
# array([ 43, 329, 246, 124, 180, 173, 167,  68,  63, 153,  30,  69, 300,
#        373, 186, 164,  22,   9,  31])

# %%
pred
# Out:
# array([ 20, 411, 243,  59, 180, 176, 217,  58,  10, 183,  30,  62, 306,
#        431, 149, 159,   7,   4,  25])

# %% [markdown]
# The trues an the preds aren't particularly close together for this point at least...  A couple of them are really quite bad in fact.  I guess this rewards not predicting many points for the smaller classes - predict the ones that you are sure about and that will get multiplied.  If you predict a lot in the big classes - it's hard to have too awful precision, and the effect will be mitigated (if you have more in the predicted than in the actual).
#
# Doesn't explain why it's so close to accuracy though.

# %% [markdown]
# ## Plot

# %%
meths
# Out:
# ['wilcoxon',
#  't-test_overestim_var',
#  'logreg',
#  'edgeR',
#  'edgeRdet',
#  'MAST',
#  'MASTdet',
#  'enets',
#  'genzel',
#  'scvi',
#  'random']

# %%
score = 'prec'

daytaname = dataset + "-class-scores-RF.npz"
dayta = np.load(path + daytaname)


methNames = {
    'rankCorr': "RankCorr",
     methods[0]: 'Wilcoxon',
     methods[1]: 't-test',
     methods[2]: 'Log. Reg.',
    'edgeR': 'edgeR',
    'edgeRdet': 'edgeRdet',
    'MAST': 'MAST',
    'MASTdet': 'MASTdet',
    'enets': 'Elastic Nets',
    'genzel': 'Spa',
    'scvi': 'scVI',
    'random': 'Random'
}

traces = []
for i,method in enumerate(['rankCorr'] + meths):
    traces.append(
        go.Scatter(x=dayta['xvals'][i], y=dayta[score][i], name=methNames[method], mode="lines+markers")
    )

# %%
for i, meth in  enumerate(['rankCorr'] + meths):
    print(np.mean(np.abs(1-np.array(dayta['mccs'][i]) - np.array(dayta['accs'][i]))))
# Out:
# 0.026426609913713078
# 0.02598825013464605
# 0.025981450006156218
# 0.026129251574490926
# 0.026285684702496943
# 0.02592680688208063
# 0.026723522144388424
# 0.02631665481055903
# 0.02705614959263609
# 0.026274243737947962
# 0.033796305223340754
# 0.05095203879593599

# %%
for i, meth in  enumerate(['rankCorr'] + meths):
    print(np.max(np.abs(1-np.array(dayta['mccs'][i]) - np.array(dayta['accs'][i]))))
# Out:
# 0.03082814677580037
# 0.027917558811622833
# 0.028350079100208814
# 0.0293960135967839
# 0.032099050005695906
# 0.03075187168629423
# 0.03160452597835672
# 0.03145043160555783
# 0.04124540786104247
# 0.028523338968961087
# 0.052094301189398506
# 0.0686652104870028

# %%
np.max(np.abs(1-np.array(dayta['prec'][i]) - np.array(dayta['accs'][i])))
# Out:
# 0.04446128098526847

# %%
iplot(traces)
# Out:
# <div id="23073152-ff51-4994-a083-58e15b03ef2b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("23073152-ff51-4994-a083-58e15b03ef2b")) {
#     Plotly.newPlot("23073152-ff51-4994-a083-58e15b03ef2b", [{"mode": "lines+markers", "name": "RankCorr", "x": [37.6, 48.8, 63.2, 76.6, 90.4, 105.6, 118.8, 132.0, 146.0, 158.0, 175.0, 186.6, 199.8, 214.8, 228.2, 242.2, 254.8, 268.0, 278.6, 291.8, 305.6, 318.0, 330.0, 343.4, 355.2, 369.2, 382.4, 395.2, 407.6, 419.4, 433.8, 445.4, 458.2, 469.2, 482.0, 492.8, 505.0, 514.6, 527.2, 538.4, 551.2, 560.6, 570.0, 579.6, 591.2, 600.4, 611.6, 624.0, 633.6, 643.4, 654.0, 662.4, 670.0, 679.4, 687.0, 696.6, 703.0, 712.2, 721.0], "y": [0.6553252359753782, 0.6924765894191774, 0.7132265558597041, 0.7091642697179824, 0.7
markers", "name": "Log. Reg.", "x": [28.0, 39.6, 51.2, 61.4, 71.8, 83.2, 94.0, 104.6, 113.6, 135.4, 155.2, 173.6, 193.6, 214.6, 261.2, 307.0, 349.0, 393.2, 435.2, 476.0, 510.8, 547.4, 581.2, 615.8, 654.2], "y": [0.6805860805860806, 0.7021978021978021, 0.7197802197802198, 0.7157509157509158, 0.7274725274725274, 0.7146520146520147, 0.7223443223443223, 0.7304029304029304, 0.7282051282051282, 0.7234432234432234, 0.7194139194139194, 0.7197802197802198, 0.7135531135531136, 0.7117216117216117, 0.7091575091575092, 0.710989010989011, 0.6996336996336996, 0.7054945054945055, 0.6879120879120879, 0.6838827838827839, 0.6919413919413919, 0.6882783882783883,  ...

# %% [markdown]
# # Zeisel plots
#
# Only show accuracy and precision since recall and mcc look very much like precison

# %%
methods = ['wilcoxon', 't-test_overestim_var', 'logreg']
meths = methods + ['edgeR', 'edgeRdet', 'MAST', 'MASTdet'] + ['enets', 'genzel', 'scvi',  'random'];

# %%
dataset = "zeisel"
path = "../zeisel/plot/"

# %%
NCname = dataset + "-class-scores.npz"
NC = np.load(path + NCname)

RFname = dataset + "-class-scores-RF.npz"
RF = np.load(path + RFname)

score1 = 'accs'
score2 = 'prec'

methNames = {
    'rankCorr': "$\mathrm{R{\small ANK}C{\small ORR}}$",
     methods[0]: 'Wilcoxon',
     methods[1]: 't-test',
     methods[2]: 'Log. Reg.',
    'edgeR': 'edgeR',
    'edgeRdet': 'edgeRdet',
    'MAST': 'MAST',
    'MASTdet': 'MASTdet',
    'enets': 'Elastic Nets',
    'genzel': '$\mathrm{ S{\small PA}}$',
    'scvi': 'scVI',
    'random': 'Random'
}

# %% [markdown]
# Color explorations

# %%
    # from https://sashat.me/2017/01/11/list-of-20-simple-distinct-colors/
    # also http://bl.ocks.org/aaizemberg/78bd3dade9593896a59d
    # also https://codepen.io/stevekearsley/pen/RRmdRP
    # dd4477
    # "#b610ba", "#66aa00",
    # 4  d62728 #2ca02c
#5  ff9896 #98df8a
    # 109618
#     colorway = ['#4363d8', '#3cb44b', '#fabebe', '#e6194B', '#ff7f0e', '#911eb4', '#42d4f4', '#f032e6',
#                 '#808000', '#800000', '#469990', '#e6beff', '#9A6324', '#fffac8', '#ffe119', '#aaffc3',
#                 '#bfef45', '#ffd8b1', '#000075', '#a9a9a9'],
    #colorway = ["#3366cc", "#ef3774", "#ff9900", "#22aa99", "#9467bd", "#c5b0d5", '#2ca02c', '#98df8a', "#8c564b",  "#0099c6", "#f032e6", '#808080', "#994499",  "#22aa99", "#aaaa11", "#6633cc", "#e67300", "#8b0707", "#651067", "#329262", "#5574a6", "#3b3eac"],

# %%
colorMap = {
    
    'rankCorr' : "#3366cc",
#    methods[0] : "#ef3774", # nice pink
    methods[0] : "#d62728", # red
    methods[1] : "#ff9900",
#    methods[2] : "#22aa99",  # green-blue (close to green)
#    methods[2] : "#576362",  #chalkboard
    methods[2] : "#17becf", # teal
    'edgeR' :  "#9467bd",
    'edgeRdet' : "#c5b0d5",
    'MAST' : '#2ca02c',
    'MASTdet': '#98df8a',
    'enets': "#8c564b",
#    'genzel' : "#0099c6", # blueish
    'genzel' : "#aec7e8", #categorical matching blue
    'scvi' : "#f032e6",
    'random' : '#808080'
    
}

# %%
colorMap = {
    
    'rankCorr' : "#3366cc",
#    methods[0] : "#ef3774", # nice pink
    methods[0] : "#d62728", # red
    methods[1] : "#ff9900",
#    methods[2] : "#22aa99",  # green-blue (close to green)
    methods[2] : "#2ca02c",  #chalkboard
    'edgeR' :  "#9467bd",
    'edgeRdet' : "#c5b0d5",
    'MAST' : '#17becf',
    'MASTdet': '#9edae5',
    'enets': "#8c564b",
#    'genzel' : "#0099c6", # blueish
    'genzel' : "#bcbd22", #vom
    'scvi' : "#f032e6",
    'random' : '#808080'
    
}

# %%
styles = []
for i, meth in enumerate(['rankCorr'] + meths):
    
    styles.append(
        dict(
            name = methNames[meth],
            legendgroup = methNames[meth],
            mode = "lines+markers",
            line = dict(
                color = colorMap[meth]
            ),
            marker = dict(
                color = colorMap[meth]
            )
        )
    )

# %%
traces11 = []
for i,method in enumerate(['rankCorr'] + meths[:-1]):
    traces11.append(
        go.Scatter(x=NC['xvals'][i], y=NC[score1][i], **styles[i])
    )
    
traces11b = []
for i,method in enumerate(['rankCorr'] + meths[:-1]):
    traces11b.append(
        go.Scatter(x=NC['xvals'][i], y=NC[score1][i], showlegend=False,**styles[i])
    )
    
traces12 = []
for i,method in enumerate(['rankCorr'] + meths[:-1]):
    traces12.append(
        go.Scatter(x=NC['xvals'][i], y=NC[score2][i], name=methNames[method], mode="lines+markers")
    ) 

traces21 = []
for i,method in enumerate(['rankCorr'] + meths[:-1]):
    traces21.append(
        go.Scatter(x=RF['xvals'][i], y=RF[score1][i], showlegend=False,  **styles[i]) # xaxis='x2',
    ) 
    
traces22 = []
for i,method in enumerate(['rankCorr'] + meths[:-1]):
    traces22.append(
        go.Scatter(x=RF['xvals'][i], y=RF[score2][i], name=methNames[method], mode="lines+markers")
    )

# %%
layout1 = go.Layout(
    colorway = [colorMap[meth] for meth in ['rankCorr'] + meths],
    font = dict(
            family='CMU Serif'
    ),
    showlegend=False,
    xaxis=dict(
        title='Number of markers',
        showgrid=False,
        ticks='inside',
        showline=True,
        mirror='ticks',
        #range=[10,170],
        range=[0,420],
        titlefont=dict(
            #family='Computer Modern',
            size=30,
            color='#000'
        ),
        tickfont=dict(
            size=24,
            color='#000'
        )
    ),
    yaxis=dict(
        title='Classification error rate',
        showgrid=False,
        ticks='inside',
        showline=True,
        mirror='ticks',
        #range=[0.03,0.16],
        titlefont=dict(
            #family='Computer Modern',
            size=30,
            color='#000'
        ),
        tickfont=dict(
            size=24,
            color='#000'
        )
    ),
    legend=dict(
        #x=0,
        #y=1,
        #traceorder='normal',
        font=dict(
            #family='Computer Modern',
            size=20,
            #color='#000'
        ),
        #bgcolor='#E2E2E2',
        #bordercolor='#FFFFFF',
        #borderwidth=2
    ),
    margin=go.layout.Margin(
        l=100,
        r=10,
        b=90,
        t=10,
        #pad=4
    ),
)

layout2 = go.Layout(
    colorway = [colorMap[meth] for meth in ['rankCorr'] + meths],
    font = dict(
            family='CMU Serif'
    ),
    #showlegend=False,
    xaxis=dict(
        title='Number of markers',
        showgrid=False,
        ticks='outside',
        showline=True,
        range=[10,170],
        titlefont=dict(
            #family='Computer Modern',
            size=20,
        ),
        tickfont=dict(
            size=16,
        )
    ),
    yaxis=dict(
        title='Average precision',
        titlefont=dict(
            #family='Computer Modern',
            size=20,
        ),
        tickfont=dict(
            size=16,
        )
    ),
    legend=dict(
        #x=0,
        #y=1,
        #traceorder='normal',
        font=dict(
            #family='Computer Modern',
            size=16,
            color='#000'
        ),
        #bgcolor='#E2E2E2',
        #bordercolor='#FFFFFF',
        #borderwidth=2
    ),
    margin=go.layout.Margin(
        #l=50,
        #r=10,
        #b=50,
        #t=10,
        #pad=4
    ),
)

# %%
iplot({'data': traces21, 'layout': layout1})
# Out:
# <div id="a84e0cbf-f85d-429d-a034-2c5867b6d34e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("a84e0cbf-f85d-429d-a034-2c5867b6d34e")) {
#     Plotly.newPlot("a84e0cbf-f85d-429d-a034-2c5867b6d34e", [{"legendgroup": "$\\mathrm{R{\\small ANK}C{\\small ORR}}$", "line": {"color": "#3366cc"}, "marker": {"color": "#3366cc"}, "mode": "lines+markers", "name": "$\\mathrm{R{\\small ANK}C{\\small ORR}}$", "showlegend": false, "x": [19.8, 21.8, 22.8, 25.4, 32.0, 34.6, 37.2, 41.4, 43.2, 47.0, 51.0, 54.2, 57.4, 59.8, 62.2, 64.8, 67.0, 69.4, 72.2, 73.6, 75.6, 78.6, 82.0, 83.6, 85.4, 88.2, 91.0, 94.2, 97.6, 100.8, 103.8, 105.4, 109.4, 113.8, 115.8, 118.8, 121.6, 123.8, 125.6, 127.6, 129.8, 134.0, 136.8, 141.2, 145.0, 147.6, 150.2, 153.2, 157.4, 160.8, 166.0, 169.6, 172.2, 175.4, 177.2, 181.2, 182.4, 185.6, 188.8, 190.4, 193.8, 197.2, 200.6, 203.8, 205.6, 206.4, 210.0, 212.6, 216.0, 220.0, 222.4, 225.8, 228.0, 231.6, 233.6, 237.0, 239.2, 241.8, 244.8, 248.2, 250.4, 253.2, 255.4, 258.2, 260.6, 264.4, 266.2, 270.2, 272.2, 274.6, 276.6, 278.8, 283.2, 285.8, 288.4, 292.0, 294.6, 299.4, 301.8, 304.4, 308.6, 311.0, 313.4, 316.0, 317.8, 321.6, 324.4, 327.2, 329.8, 332.6, 335.8, 337.8, 340.6, 342.6, 345.0, 346.6, 348.8, 350.6, 353.2, 355.2, 357.4, 360.4, 362.6, 365.2, 368.0, 370.0, 370.6, 373.2, 375.2, 376.6, 380.6, 382.8, 384.8, 388.0, 390.2, 393.2, 394.8, 397.6, 401.0, 403.4, 405.6, 408.4, 411.2, 413.2, 416.8, 419.0, 423.0, 425.6, 428.2, 430.6, 432.8, 435.0, 436.6, 440.6, 443.0, 445.6, 447.4, 451.0, 452.8, 456.4, 459.4, 462.4, 465.8, 468.8, 470.8, 472.8, 475.0, 477.8, 481.6, 486.0, 489.2, 491.2, 492.8, 496.4, 498.8, 502.0, 505.8, 509.0, 512.0, 514.2, 517.4, 521.2, 524.0, 526.0, 528.2], "y": [0.07354409317803656, 0.07454242928452581, 0.07088186356073212, 0.06988352745424298, 0.06489184692179706, 0.06489184692179706, 0.06422628951747089, 0.06123128119800336, 0.05823627287853572, 0.05790349417637275, 0.053577371048252886, 0.05490848585690511, 0.05623960066555744, 0.05524126455906819, 0.053577371048252886, 0.0532445923460898, 0.05257903494176375, 0.0515806988352745, 0.05191347753743758, 0.0532445923460898, 0.0515806988352745, 0.0515806988352745, 0.0532445923460898, 0.050249584026622274, 0.04991680532445919, 0.050249584026622274, 0.04958402662229622, 0.04792013311148091, 0.051247920133111524, 0.05058236272878536, 0.050249584026622274, 0.04891846921797005, 0.049251247920133134, 0.04891846921797005, 0.048252911813643884, 0.050249584026622274, 0.05058236272878536, 0.050249584026622274, 0.046256239600665605, 0.05058236272878536, 0.048252911813643884, 0.04792013311148091, 0.04592346089850252, 0.04792013311148091, 0.04692179700499166, 0.05058236272878536, 0.04858569051580697, 0.04758735440931783, 0.046256239600665605, 0.048252911813643884, 0.04758735440931783, 0.04559068219633944, 0.05191347753743758, 0.046256239600665605, 0.05058236272878536, 0.04692179700499166, 0.04692179700499166, 0.048252911813643884, 0.04792013311148091, 0.04692179700499166, 0.04392678868552413, 0.044259567387687215, 0.04559068219633944, 0.04559068219633944, 0.04658901830282858, 0.04692179700499166, 0.048252911813643884, 0.04792013311148091, 0.046256239600665605, 0.04758735440931783, 0.048252911813643884, 0.04692179700499166, 0.04492512479201327, 0.04758735440931783, 0.04692179700499166, 0.047254575707154745, 0.04492512479201327, 0.04692179700499166, 0.04492512479201327, 0.0445923460898503, 0.04592346089850252, 0.04492512479201327, 0.04392678868552413, 0.04692179700499166, 0.04592346089850252, 0.046256239600665605, 0.04792013311148091, 0.047254575707154745, 0.04891846921797005, 0.047254575707154745, 0.04559068219633944, 0.04492512479201327, 0.04658901830282858, 0.04559068219633944, 0.046256239600665605, 0.04559068219633944, 0.047254575707154745, 0.04559068219633944, 0.0445923460898503, 0.04692179700499166, 0.04559068219633944, 0.04492512479201327, 0.043261231281197965, 0.04392678868552413, 0.04559068219633944, 0.04559068219633944, 0.046256239600665605, 0.04292845257903499, 0.04259567387687191, 0.04858569051580697, 0.0445923460898503, 0.0445923460898503, 0.04392678868552413, 0.044259567387687215, 0.04259567387687191, 0.04658 ...

# %%
pio.write_json({'data': traces21, 'layout': layout1}, "pics2/zeisel-rf-acc.json")

# %%
from plotly import tools

# %%
# ?tools.make_subplots

# %%
fig = tools.make_subplots(rows=1, cols=2, horizontal_spacing=0.12)

for trace in traces11:
    fig.append_trace(trace, 1, 1)
    
for trace in traces11b:
    fig.append_trace(trace, 1, 2)
    
fig['layout']['xaxis1'].update(
    title='Number of markers',
    showgrid=False,
    ticks='inside',
    showline=True,
    mirror='ticks',
    range=[0,420],
    titlefont=dict(
        #family='Computer Modern',
        size=20,
    ),
    tickfont=dict(
        size=20,
    )
)

fig['layout']['xaxis2'].update(
    title='Number of markers',
    showgrid=False,
    ticks='inside',
    showline=True,
    mirror='ticks',
    range=[10,130],
    titlefont=dict(
        #family='Computer Modern',
        size=20,
    ),
    tickfont=dict(
        size=20,
        color="#000"
    )
)

fig['layout']['yaxis1'].update(
    title='Classification error rate (NCC)',
    showgrid=False,
    ticks='inside',
    showline=True,
    mirror='ticks',
    titlefont=dict(
        #family='Computer Modern',
        size=20,
    ),
    tickfont=dict(
        size=20,
    )
)

fig['layout']['yaxis2'].update(
    title='Classification error rate (RFC)',
    showgrid=False,
    ticks='inside',
    showline=True,
    mirror='ticks',
    titlefont=dict(
        #family='Computer Modern',
        size=20,
    ),
    tickfont=dict(
        size=20,
        
    )
)


fig['layout'].update(
    font = dict(
            family='CMU Serif'
    ),
    margin=go.layout.Margin(
        #l=50,
        r=20,
        b=60,
        #t=10,
        #pad=4
    )
)
fig['layout']['legend'].update(
    orientation = 'h',
    y=1.3,
    font=dict(
        #family='Computer Modern',
        size=18,
        #color='#000'
    )
)

#fig['layout']['grid'].update(xgap=0.8)
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]  [ (1,2) x2,y2 ]
# layout.Legend({
#     'font': {'size': 18}, 'orientation': 'h', 'y': 1.3
# })

# %%
iplot(fig)
# Out:
# <div id="e062c837-09b1-40de-9778-9728237c56f0" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("e062c837-09b1-40de-9778-9728237c56f0")) {
#     Plotly.newPlot("e062c837-09b1-40de-9778-9728237c56f0", [{"legendgroup": "$\\mathrm{\\small R{\\scriptsize ANK}C{\\scriptsize ORR}}$", "line": {"color": "#3366cc"}, "marker": {"color": "#3366cc"}, "mode": "lines+markers", "name": "$\\mathrm{\\small R{\\scriptsize ANK}C{\\scriptsize ORR}}$", "x": [19.8, 21.8, 22.8, 25.4, 32.0, 34.6, 37.2, 41.4, 43.2, 47.0, 51.0, 54.2, 57.4, 59.8, 62.2, 64.8, 67.0, 69.4, 72.2, 73.6, 75.6, 78.6, 82.0, 83.6, 85.4, 88.2, 91.0, 94.2, 97.6, 100.8, 103.8, 105.4, 109.4, 113.8, 115.8, 118.8, 121.6, 123.8, 125.6, 127.6, 129.8, 134.0, 136.8, 141.2, 145.0, 147.6, 150.2, 153.2, 157.4, 160.8, 166.0, 169.6, 172.2, 175.4, 177.2, 181.2, 182.4, 185.6, 188.8, 190.4, 193.8, 197.2, 200.6, 203.8, 205.6, 206.4, 210.0, 212.6, 216.0, 220.0, 222.4, 225.8, 228.0, 231.6, 233.6, 237.0, 239.2, 241.8, 244.8, 248.2, 250.4, 253.2, 255.4, 258.2, 260.6, 264.4, 266.2, 270.2, 272.2, 274.6, 276.6, 278.8, 283.2, 285.8, 288.4, 292.0, 294.6, 299.4, 301.8, 304.4, 308.6, 311.0, 313.4, 316.0, 317.8, 321.6, 324.4, 327.2, 329.8, 332.6, 335.8, 337.8, 340.6, 342.6, 345.0, 346.6, 348.8, 350.6, 353.2, 355.2, 357.4, 360.4, 362.6, 365.2, 368.0, 370.0, 370.6, 373.2, 375.2, 376.6, 380.6, 382.8, 384.8, 388.0, 390.2, 393.2, 394.8, 397.6, 401.0, 403.4, 405.6, 408.4, 411.2, 413.2, 416.8, 419.0, 423.0, 425.6, 428.2, 430.6, 432.8, 435.0, 436.6, 440.6, 443.0, 445.6, 447.4, 451.0, 452.8, 456.4, 459.4, 462.4, 465.8, 468.8, 470.8, 472.8, 475.0, 477.8, 481.6, 486.0, 489.2, 491.2, 492.8, 496.4, 498.8, 502.0, 505.8, 509.0, 512.0, 514
389351081530781, 0.06422628951747089, 0.06522462562396003, 0.06489184692179706, 0.06622296173044928, 0.06655574043261236, 0.06622296173044928, 0.06655574043261236, 0.0658901830282862, 0.06555740432612311, 0.0658901830282862, 0.0658901830282862, 0.0658901830282862, 0.06522462562396003, 0.06422628951747089, 0.06389351081530781, 0.06289517470881867, 0.06256239600665559, 0.06422628951747089, 0.06289517470881867, 0.06256239600665559, 0.0622296173044925, 0.0622296173044925, 0.061564059900166335, 0.0622296173044925, 0.06123128119800336, 0.06123128119800336, 0.06089850249584028, 0.05990016638935103, 0.059567387687188056, 0.05990016638935103, 0.05990016638935103, 0.058569051580698805, 0.058569051580698805, 0.05823627287853572, 0.05823627287853572, 0.057570715474209666, 0.05723793677204658, 0.057570715474209666, 0.056572379367720416, 0.05723793677204658, 0.05623960066555744, 0.05623960066555744, 0.05590682196339436, 0.05457570715474214, 0.05490848585690511, 0.054 ...

# %% [markdown]
# # Paul plots

# %%
dataset = "paul15"
path = "paul/"

# %%
NCname = dataset + "-class-scores.npz"
NC = np.load(path + NCname)

RFname = dataset + "-class-scores-RF.npz"
RF = np.load(path + RFname)

score1 = 'accs'
score2 = 'prec'

methNames = {
    'rankCorr': "$\mathrm{\small R{\scriptsize ANK}C{\scriptsize ORR}}$",
     methods[0]: 'Wilcoxon',
     methods[1]: 't-test',
     methods[2]: 'Log. Reg.',
    'edgeR': 'edgeR',
    'edgeRdet': 'edgeRdet',
    'MAST': 'MAST',
    'MASTdet': 'MASTdet',
    'enets': 'Elastic Nets',
    'genzel': '$\mathrm{\small S{\scriptsize PA}}$',
    'scvi': 'scVI',
    'random': 'Random'
}

# %%
traces11 = []
for i,method in enumerate(['rankCorr'] + meths[:-1]):
    arglist = np.argsort(NC['xvals'][i])
    traces11.append(
        go.Scatter(x=NC['xvals'][i][arglist], y=np.array(NC[score1][i])[arglist], name=methNames[method], mode="lines+markers")
    ) 
    
traces12 = []
for i,method in enumerate(['rankCorr'] + meths[:-1]):
    arglist = np.argsort(NC['xvals'][i])
    traces12.append(
        go.Scatter(x=NC['xvals'][i][arglist], y=np.array(NC[score2][i])[arglist], name=methNames[method], mode="lines+markers")
    ) 

traces21 = []
for i,method in enumerate(['rankCorr'] + meths[:-1]):
    arglist = np.argsort(RF['xvals'][i])
    traces21.append(
        go.Scatter(x=RF['xvals'][i][arglist], y=np.array(RF[score1][i])[arglist], name=methNames[method], mode="lines+markers")
    ) 
    
traces22 = []
for i,method in enumerate(['rankCorr'] + meths[:-1]):
    arglist = np.argsort(RF['xvals'][i])
    traces22.append(
        go.Scatter(x=RF['xvals'][i][arglist], y=np.array(RF[score2][i])[arglist], name=methNames[method], mode="lines+markers")
    )

# %%
layout1 = go.Layout(
    
    colorway = [colorMap[meth] for meth in ['rankCorr'] + meths],
    font = dict(
            family='CMU Serif'
    ),
    showlegend=False,
    xaxis=dict(
        title='Number of markers',
        showgrid=False,
        ticks='inside',
        showline=True,
        mirror='ticks',
        #range=[20,230], # zoom ncc
        range=[20,350], # zoom rfc
        #range=[0,550],
        tick0=20,
        dtick=40,
        #tickmode='linear',
        titlefont=dict(
            #family='Computer Modern',
            size=30,
            color='#000'
        ),
        tickfont=dict(
            size=24,
            color='#000'
        )
    ),
    yaxis=dict(
        title='Classification error rate',
        showgrid=False,
        ticks='inside',
        showline=True,
        mirror='ticks',
        #range=[0.3,0.45], # zoom ncc
        #range=[0.27,0.55], # ncc
        #range=[0.25,0.47], # rfc
        range=[0.25,0.37], # zoom rfc
        titlefont=dict(
            #family='Computer Modern',
            size=30,
            color='#000'
        ),
        tickfont=dict(
            size=24,
            color='#000'
        )
    ),
    legend=dict(
        #x=0,
        #y=1,
        #traceorder='normal',
        font=dict(
            #family='Computer Modern',
            size=20,
            color='#000'
        ),
    ),
    margin=go.layout.Margin(
        l=100,
        r=10,
        b=90,
        t=10,
        #pad=4
    ),
)


layout2 = go.Layout(
    
    colorway = [colorMap[meth] for meth in ['rankCorr'] + meths],
    font = dict(
            family='CMU Serif'
    ),
    #showlegend=False,
    xaxis=dict(
        title='Number of markers',
        range=[0,550],
        titlefont=dict(
            #family='Computer Modern',
            size=20,
        ),
        tickfont=dict(
            size=16,
        )
    ),
    yaxis=dict(
        title='Average precision',
        titlefont=dict(
            #family='Computer Modern',
            size=20,
        ),
        tickfont=dict(
            size=16,
        )
    ),
    legend=dict(
        #x=0,
        #y=1,
        #traceorder='normal',
        font=dict(
            #family='Computer Modern',
            size=16,
            #color='#000'
        ),
        #bgcolor='#E2E2E2',
        #bordercolor='#FFFFFF',
        #borderwidth=2
    ),
    margin=go.layout.Margin(
        #l=50,
        #r=50,
        #b=100,
        t=20,
        #pad=4
    ),
)

# %%
iplot({'data': traces21, 'layout': layout1})
# Out:
# <div id="d963f6ed-2f7a-4c47-84bb-18169b018af9" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("d963f6ed-2f7a-4c47-84bb-18169b018af9")) {
#     Plotly.newPlot("d963f6ed-2f7a-4c47-84bb-18169b018af9", [{"mode": "lines+markers", "name": "$\\mathrm{\\small R{\\scriptsize ANK}C{\\scriptsize ORR}}$", "x": [37.6, 48.8, 63.2, 76.6, 90.4, 105.6, 118.8, 132.0, 146.0, 158.0, 175.0, 186.6, 199.8, 214.8, 228.2, 242.2, 254.8, 268.0, 278.6, 291.8, 305.6, 318.0, 330.0, 343.4, 355.2, 369.2, 382.4, 395.2, 407.6, 419.4, 433.8, 445.4, 458.2, 469.2, 482.0, 492.8, 505.0, 514.6, 527.2, 538.4, 551.2, 560.6, 570.0, 579.6, 591.2, 600.4, 611.6, 624.0, 633.6, 643.4, 654.0, 662.4, 670.0, 679.4, 687.0, 696.6, 703.0, 712.2, 721.0], "y": [0.33553113553113556, 0.30109890109890114, 0.28424908424908424, 0.28424908424908424, 0.2805860805860806, 0.27875457875457876, 0.2816849816849817, 0.2794871794871795, 0.28608058608058606, 0.27765567765567767, 0.2901098901098901, 0.289010989010989, 0.2897435897435897, 0.28827838827838825, 0.2765567765567766, 0.29047619047619044, 0.29047619047619044, 0.2875457875457875, 0.27912087912087913, 0.2959706959706959, 0.289010989010989, 0.2908424908424908, 0.2912087912087912, 0.29157509157509154, 0.28498168498168497, 0.2963369963369963, 0.2912087912087912, 0.29560439560439555, 0.2992673992673993, 0.2919413919413919, 0.29377289377289373, 0.2908424908424908, 0.30219780219780223,